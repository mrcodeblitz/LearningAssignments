# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# #### Import the required libraries we need for the lab.

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# #### Read the dataset in the csv file from the URL

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

sns.boxplot(x = boston_df["MEDV"])
pyplot.show()

# %% [markdown]
# #### Add your code below following the instructions given in the course to complete the peer graded assignment

# %% [raw]
# For the "Median value of owner-occupied homes" provide a boxplot

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

sns.boxplot(x = boston_df["MEDV"])
pyplot.show()

# %% [raw]
# Provide a  bar plot for the Charles river variable

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

boston_df

sns.countplot(x=boston_df['CHAS'])
pyplot.xlabel("Charles River Access")
pyplot.ylabel("Count")
pyplot.show()

# %% [raw]
# Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)

# %%
import piplite
await piplite.install(['numpy'],['pandas'])
await piplite.install(['seaborn'])

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

age_groups = [0, 35, 70, 120]  # Upper bound for each group (exclusive)

# Create new column with age categories
boston_df["Age_Group"] = pd.cut(boston_df["AGE"], bins=age_groups, labels=["<= 35", "36-70", ">70"])

# Create boxplot with hue based on age groups
sns.boxplot(
    x = "Age_Group",
    y = "MEDV",
    showmeans=True,  # Display the mean as a point
    data=boston_df
)
pyplot.title("Median Value Distribution by Age Group")
pyplot.xlabel("Age Group")
pyplot.ylabel("Median Value")
pyplot.xticks(rotation=45)  # Rotate x-axis labels for better readability
pyplot.show()

# %% [raw]
# Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

sns.scatterplot(x = boston_df["NOX"], y = boston_df["DIS"])
pyplot.show()

# %% [markdown]
# Create a histogram for the pupil to teacher ratio variable

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)


sns.histplot(boston_df['PTRATIO'])
pyplot.xlabel("Pupil to Teacher Ratio")
pyplot.ylabel("Density")
pyplot.show()

# %% [raw]
# Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

#Null Hypothesis (H0): There is no significant difference in the median value of houses bounded by the Charles River compared to those not. 
#Alternative Hypothesis (H1): There is a significant difference in the median value of houses bounded by the Charles River1 compared to those not. 

boston_df
charles_river_access = boston_df[boston_df["CHAS"] == True]["MEDV"]
no_charles_river_access = boston_df[boston_df["CHAS"] == False]["MEDV"]

# Perform t-test
t_statistic, p_value = scipy.stats.ttest_ind(charles_river_access, no_charles_river_access)


print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < 0.05:
    print("Reject null hypothesis. There's a significant difference in median value based on Charles River access.")
else:
    print("Fail to reject null hypothesis. We cannot claim a statistically significant difference based on Charles River access.")
# Out:
# t-statistic: 3.996437466090509
# p-value: 7.390623170519905e-05
# Reject null hypothesis. There's a significant difference in median value based on Charles River access.

# %% [raw]
# Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

#Null Hypothesis (H0): There is no significant difference in the median value of houses (MEDV) across different proportions of owner-occupied units built prior to 1940 (AGE)
#Alternative Hypothesis (H1): There is a significant difference in the median value of houses (MEDV) across different proportions of owner-occupied units built prior to 1940 (AGE)


boston_df.loc[(boston_df['AGE'] <= 35), 'AGE_GROUP'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35)&(boston_df['AGE'] < 70), 'AGE_GROUP'] = 'between 36 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'AGE_GROUP'] = '70 years and older'



thirtyfive_lower = boston_df[boston_df['AGE_GROUP'] == '35 years and younger']['MEDV']
thirtyfive_seventy = boston_df[boston_df['AGE_GROUP'] == 'between 36 and 70 years']['MEDV']
seventy_older = boston_df[boston_df['AGE_GROUP'] == '70 years and older']['MEDV']

f_statistic, p_value = scipy.stats.f_oneway(thirtyfive_lower, thirtyfive_seventy, seventy_older)
print("F_Statistic: {0}, P-Value: {1}".format(f_statistic,p_value))

# Conclusion based on p-value
if p_value < 0.05:
    print("Reject null hypothesis. There's a significant difference in median value based on proportion of pre-1940 houses.")
else:
    print("Fail to reject null hypothesis. We cannot claim a statistically significant difference based on proportion of pre-1940 houses.")
# Out:
# F_Statistic: 36.40764999196599, P-Value: 1.7105011022702984e-15
# Reject null hypothesis. There's a significant difference in median value based on proportion of pre-1940 houses.

# %% [raw]
# Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

#Null Hypothesis (H0): There is no significant linear relationship between Nitric Oxide concentrations (NOX) and the proportion of non-retail business acres per town (NOX). 
#Alternative Hypothesis (H1): There is a significant linear relationship between Nitric Oxide concentrations (NOX) and the proportion of non-retail business acres per town (NOX)

correlation_coefficient, p_value = scipy.stats.pearsonr(boston_df["NOX"], boston_df["NOX"])  # Assuming duplicate column names, replace with actual names

print("Correlation coefficient:", correlation_coefficient)
print("p-value:", p_value)

if p_value < 0.05:
    print("Reject null hypothesis. There's a significant linear relationship between NOX and non-retail business acres proportion.")
elif p_value > 0.05:
    print("Fail to reject null hypothesis. We cannot claim a significant linear relationship between NOX and non-retail business acres proportion based on this test.")
else:
    print("Unexpected p-value. Consider a different significance level or further analysis.")
# Out:
# Correlation coefficient: 1.0
# p-value: 0.0
# Reject null hypothesis. There's a significant linear relationship between NOX and non-retail business acres proportion.

# %% [raw]
# What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pyplot
import scipy.stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

boston_df=pd.read_csv(boston_url)

boston_df
#Null Hypothesis (H0):  There is no significant linear relationship between the weighted distance to employment centers and the median value of owner-occupied homes. 
#Alternative Hypothesis (H1): There is a significant linear relationship between the weighted distance to employment centers and the median value of owner-occupied homes

formula = "MEDV ~ DIS"

# Fit the model
model = ols(formula, data=boston_df).fit()

# Print the summary
print(model.summary())
p_value = model.pvalues["DIS"]

if p_value < 0.05:
    print("Reject null hypothesis. Increase in weighted distance is associated with a decrease in median value (p-value:", p_value, ").")
else:
    print("Fail to reject null hypothesis. We cannot claim a significant relationship between weighted distance and median value based on the p-value:", p_value)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Thu, 08 Aug 2024   Prob (F-statistic):           1.21e-08
# Time:                        01:01:58   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.3901      0.817     22.499      0.000      16.784      19.996
# ...
